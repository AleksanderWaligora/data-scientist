# %%
from photo_style_change import ImageGenerator

# %%
height = 768

width = 568

canny=True

prompt = """raw, masterpiece,  high quality, 8k, dog, cavalier king charles spaniel, spaniel, cartoon, black and white, old"""

negative_prompt="low quality, "

ip_adapt_path = "/content/drive/MyDrive/images/source/style.jpg"

canny_img_path = "/content/drive/MyDrive/images/source/dog.JPEG"

generator = ImageGenerator(path_img_adapter=ip_adapt_path, path_img_canny=canny_img_path, width=width, height=height,is_canny=canny)

generator.generate_images(prompt,negative_prompt)

generator.save_generated_images("/content/drive/MyDrive/images/generated")
